# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen as uReq
import requests
import re
import cssutils

# %%
query = str(1)
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36"}
response = requests.get(f"https://www.flipkart.com/samsung-galaxy-s22-plus-5g-phantom-black-128-gb/product-reviews/itm7fd318a27dcd7?pid=MOBGGG2YUGAYANRQ&lid=LSTMOBGGG2YUGAYANRQQF31UI&marketplace=FLIPKART&page={query}")

# %%
soup = BeautifulSoup(response.content, "html.parser")
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
reviews=soup.find_all(attrs={"class":"t-ZTKy"})
# print(reviews)

# for i in reviews:
#     rating=i.find_all(attrs={"class":"_3LWZlK _1BLPMq"})
print(reviews[0].text.strip())
# Out:
# Pro grade camera, battery backup is slightly less. Rest overall Performance  are tremendous.READ MORE

# %%
rating = soup.find_all(attrs={"class":"_3LWZlK _1BLPMq"}) 
print(rating[0].text.strip())
# Out:
# 4

# %%
titel = soup.find_all("p", attrs={"class":"_2-N8zT"})
titel[0].text.strip()
# Out:
# 'Pretty good'

# %%
name_of_customer = soup.find_all("p",attrs={"class":"_2sc7ZR _2V5EHH"})
name_of_customer[0].text.strip()
# Out:
# 'Rajiv Kumar'
